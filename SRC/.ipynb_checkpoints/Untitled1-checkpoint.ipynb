# %%
import numpy             as np
import matplotlib.pyplot as plt

# %%
path = '/Users/Arroy javier/Desktop/MCIB/MCIB-19-P/data/Señales adquirid/'
fname = 'Med4.txt'

# %%
data = np.loadtxt(path+fname,delimiter='\t',dtype='str')

# %%
signal=data[:,:-1].astype(float)
#t = signal[ : , 0]*60

# %%
SO2=data[:,1]
RESP=data[:,2]
EMG=data[:,3]
PUL=data[:,4]
ECG=data[:,5]

# %%
from scipy.signal import hann
from scipy        import fftpack as fft
from scipy.signal import hann
from scipy.signal import chebwin
from scipy.signal import blackman
from scipy        import fftpack as fft
#print(len(EMG))
#print(len(w))

# %%
N=SO2.shape[0]
SO2 = SO2.astype('float')
#Ventana Hann
F  = fft.fft(SO2, axis=0)
F  = 20* np.log(np.abs(F))

w=hann(N)
Fw= fft.fft(SO2*w)
Fw=20*np.log10(np.abs(Fw))
f  = np.linspace(0, 1000/2, N//2)
plt.figure(figsize=(10,7))
plt.subplot(3,1,1)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f,Fw[0:N//2],color='red')
plt.title("SO2, ventana: chebwin") 
plt.grid(True)


#Ventana Cheb
w  = chebwin(N, 100)
Fw = fft.fft(SO2*w)
Fw = 20* np.log(np.abs(Fw))
plt.figure(figsize = (10,7))
plt.subplot(3,1,2)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f, Fw[0:N//2], color='red')
plt.title("SO2, ventana: chebwin") 
plt.grid(True)

#Ventana Blackman
w  = blackman(N)
Fw = fft.fft(SO2*w)
Fw = 20* np.log(np.abs(Fw))
plt.figure(figsize = (10,7))
plt.subplot(3,1,2)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f, Fw[0:N//2], color='red')
plt.title("SO2, ventana: chebwin") 
plt.grid(True)

# %%
#Respiracion

N=RESP.shape[0]
RESP = RESP.astype('float')
#Ventana Hann
F  = fft.fft(RESP, axis=0)
F  = 20* np.log(np.abs(F))

w=hann(N)
Fw= fft.fft(RESP*w)
Fw=20*np.log10(np.abs(Fw))
f  = np.linspace(0, 1000/2, N//2)
plt.figure(figsize=(10,7))
plt.subplot(3,1,1)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f,Fw[0:N//2],color='red')
plt.title("RESP, ventana: chebwin") 
plt.grid(True)


#Ventana Cheb
w  = chebwin(N, 100)
Fw = fft.fft(RESP*w)
Fw = 20* np.log(np.abs(Fw))
plt.figure(figsize = (10,7))
plt.subplot(3,1,2)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f, Fw[0:N//2], color='red')
plt.title("RESP, ventana: chebwin") 
plt.grid(True)

#Ventana Blackman
w  = blackman(N)
Fw = fft.fft(RESP*w)
Fw = 20* np.log(np.abs(Fw))
plt.figure(figsize = (10,7))
plt.subplot(3,1,2)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f, Fw[0:N//2], color='red')
plt.title("RESP, ventana: chebwin") 
plt.grid(True)

# %%
#EMG

N=EMG.shape[0]
EMG = EMG.astype('float')
#Ventana Hann
F  = fft.fft(EMG, axis=0)
F  = 20* np.log(np.abs(F))

w=hann(N)
Fw= fft.fft(EMG*w)
Fw=20*np.log10(np.abs(Fw))
f  = np.linspace(0, 1000/2, N//2)
plt.figure(figsize=(10,7))
plt.subplot(3,1,1)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f,Fw[0:N//2],color='red')
plt.title("EMG, ventana: chebwin") 
plt.grid(True)


#Ventana Cheb
w  = chebwin(N, 100)
Fw = fft.fft(EMG*w)
Fw = 20* np.log(np.abs(Fw))
plt.figure(figsize = (10,7))
plt.subplot(3,1,2)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f, Fw[0:N//2], color='red')
plt.title("EMG, ventana: chebwin") 
plt.grid(True)

#Ventana Blackman
w  = blackman(N)
Fw = fft.fft(EMG*w)
Fw = 20* np.log(np.abs(Fw))
plt.figure(figsize = (10,7))
plt.subplot(3,1,2)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f, Fw[0:N//2], color='red')
plt.title("EMG, ventana: chebwin") 
plt.grid(True)

# %%
#PULSO
N=PUL.shape[0]
PUL = PUL.astype('float')
#Ventana Hann
F  = fft.fft(PUL, axis=0)
F  = 20* np.log(np.abs(F))

w=hann(N)
Fw= fft.fft(PUL*w)
Fw=20*np.log10(np.abs(Fw))
f  = np.linspace(0, 1000/2, N//2)
plt.figure(figsize=(10,7))
plt.subplot(3,1,1)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f,Fw[0:N//2],color='red')
plt.title("PUL, ventana: chebwin") 
plt.grid(True)


#Ventana Cheb
w  = chebwin(N, 100)
Fw = fft.fft(PUL*w)
Fw = 20* np.log(np.abs(Fw))
plt.figure(figsize = (10,7))
plt.subplot(3,1,2)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f, Fw[0:N//2], color='red')
plt.title("PUL, ventana: chebwin") 
plt.grid(True)

#Ventana Blackman
w  = blackman(N)
Fw = fft.fft(PUL*w)
Fw = 20* np.log(np.abs(Fw))
plt.figure(figsize = (10,7))
plt.subplot(3,1,2)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f, Fw[0:N//2], color='red')
plt.title("PUL, ventana: chebwin") 
plt.grid(True)
print(Fw)
# Out:
# [175.32917124 167.55564253 149.70761493 ... 143.80099915 149.70761493
#  167.55564253]

# %%
#ECG

N=ECG.shape[0]
ECG = ECG.astype('float')
#Ventana Hann
F  = fft.fft(ECG, axis=0)
F  = 20* np.log(np.abs(F))

w=hann(N)
Fw= fft.fft(ECG*w)
Fw=20*np.log10(np.abs(Fw))
f  = np.linspace(0, 1000/2, N//2)
plt.figure(figsize=(10,7))
plt.subplot(3,1,1)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f,Fw[0:N//2],color='red')
plt.title("ECG, ventana: chebwin") 
plt.grid(True)


#Ventana Cheb
w  = chebwin(N, 100)
Fw = fft.fft(ECG*w)
Fw = 20* np.log(np.abs(Fw))
plt.figure(figsize = (10,7))
plt.subplot(3,1,2)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f, Fw[0:N//2], color='red')
plt.title("ECG, ventana: chebwin") 
plt.grid(True)

#Ventana Blackman
w  = blackman(N)
Fw = fft.fft(ECG*w)
Fw = 20* np.log(np.abs(Fw))
plt.figure(figsize = (10,7))
plt.subplot(3,1,2)
plt.plot(f,F[0:N//2],color='black')
plt.plot(f, Fw[0:N//2], color='red')
plt.title("ECG, ventana: chebwin") 
plt.grid(True)

# %%
#PSD
def PSD (signal,l):
#s_SO2=fft.fft(SO2[0:500])
#k=SO2.shape//500
#l=1024
    i=1
    N=signal.shape[0]
    psd=[]
    for i in range (i,N,l):
        ps=fft.fft(signal[i:i+l])
        psd.append(20*np.log(np.abs(ps)))
        psd=np.array(psd[:-1])
        return psd
print(psd.shape)
# Out:
# (114, 1024)

# %%
Signal=SO2
l=1024
r = PSD(SO2, l)
#print( r[0]  )
#print( r[1:] )

# %%
#import statistics
#prom_psd=statistics.mean(psd)

psd.mean(axis=0).shape

# %%
#Filtro butter orden 4, cut freq 0.01
b, a = signal.butter(10,0.01, output='ba')

# %%
from scipy import signal
#help(print(signal.freqz))
w,h=signal.freqz(b, a)
w.shape
h.shape

angles = np.unwrap(np.angle(h))

plt.figure(figsize=(10,7))
plt.title('Digital filter frequency response')
plt.plot(w, 20 * np.log10(abs(h)), 'b')
plt.plot(w, angles, 'g')
#plt.ylabel('Amplitud [dB]', color='b')
plt.ylabel('Angle (radians)', color='g')
plt.xlabel('Frecuencia [rad/muestra]')
plt.grid(True)

# %%
i=1
N=SO2.shape[0]
l=1024
#pm=[]
pmv=[]
md=[]
for i in range (i,N,l):
    pm=(SO2[i:i+l])
    pmv.append(pm)
    

pmv=np.array(pmv[:-1])# arreglo de las epocas
    
j=1
M=pmv.shape[0]

for i in range (j,M):
    m=(pmv[j:j+1])
    md.append(m.mean(axis=0))
    
md=np.array(md)  #arreglo de los promedios

for i in range (j,K):
    r=(md)

    #md.append(pmv.mean(a,axis=0))    
#pmv=np.array(psd[:-1])
#M=pmv.shape[0]

#for i in range (j,M)
 #   m=pmv[i:i+1]
  #  md.append[]

# %%
md.shape[0]

# %%
print(pm)
