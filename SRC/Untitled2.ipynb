# %%
import numpy             as np
import matplotlib.pyplot as plt

# %%
path = '/Users/Arroy javier/Desktop/MCIB/MCIB-19-P/data/Señales adquirid/'
fname = 'Med4.txt'

# %%
data = np.loadtxt(path+fname,delimiter='\t',dtype='str')
signal=data[:,:-1].astype(float)

# %%
SO2=data[:,1]
RESP=data[:,2]
EMG=data[:,3]
PUL=data[:,4]
ECG=data[:,5]
#ECG=ECG[]

# %%
T  =3
sr = 300
t  = np.linspace(0,T,sr*T)
s=np.random.normal(0,1,sr*T)

# %%
plt.figure(figsize=(12,4))
plt.plot(t,s,color='orange')
plt.grid(True)

# %%
nbins= 10
s=data[:,5]
bins = np.linspace(s.min(),s.max(),nbins) 
bins = bins[np.newaxis]
left=s[:,np.newaxis]>bins[0,:-1]
right=s[:,np.newaxis]<bins[0,1:]
hist=(left*right).sum(axis=0)
plt.bar(bins[0,:-1],hist,.2)

right.shape[0]
print(left,s.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-a10ea14327a1> in <module>
#       1 nbins= 10
#       2 s=data[:,5]
# ----> 3 bins = np.linspace(s.min(),s.max(),nbins)
#       4 bins = bins[np.newaxis]
#       5 left=s[:,np.newaxis]>bins[0,:-1]
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims, initial)
#      30 def _amin(a, axis=None, out=None, keepdims=False,
#      31           initial=_NoValue):
# ---> 32     return umr_minimum(a, axis, None, out, keepdims, initial)
#      33
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: cannot perform reduce with flexible type
