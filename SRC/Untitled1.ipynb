# %%
import numpy             as np
import matplotlib.pyplot as plt

# %%
c1 = [ 323.430, 367.159, 315.119, 336.996, 308.278];
c2 = [558.786, 712.797, 593.812, 912.439, 845.757 ];
c3 = [ 1258.253, 1084.258, 1307.850, 1558.612, 1348.343, 1426.393];
c4 = [1573.849, 1821.441, 1241.222, 1290.408, 1848.659, 1929.276];
c5 = [2670.512, 1543.034, 1928.805, 2360.062, 2802.496, 1672.019, 1877.681, 1779.979];

t1 = [1, 2, 3, 4, 5]
t2=[1, 2, 3, 4, 5]
t3=[1, 2, 3, 4, 5, 6]
t4=[1, 2, 3, 4, 5, 6]
t5=[1, 2, 3, 4, 5, 6, 7, 8]


#t1=t1.astype(float)

# %%
# Out:
# (1,)

# %%
plt.figure(figsize = (7, 10))
plt.subplot(3,2,1)
plt.plot(t1,c1,'o')

plt.subplot(3,2,2)
plt.plot(t2,c2,'o')

plt.subplot(3,2,3)
plt.plot(t3,c3,'o')

plt.subplot(3,2,4)
plt.plot(t4,c4,'o')

plt.subplot(3,2,5)
plt.plot(t5,c5,'o')
